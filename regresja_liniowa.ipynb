# %% [markdown]
# # Regresja liniowa

# %% [markdown]
# ## Przygotowanie danych

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as sm

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
url = 'https://raw.githubusercontent.com/MarylaSosna/umwf_projekt/main/df_final.csv'
df = pd.read_csv(url, parse_dates=['Date']).drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#         Date Comp     Close  Dividends  Stock Splits    CompID     Score  \
# 0 2004-02-11   SU  8.402296        0.0           0.0  GN63J3-R  0.953727
# 1 2004-02-11  GGG  6.480957        0.0           0.0  H5490W-R  0.952753
# 2 2004-02-11  WGR       NaN        NaN           NaN  V0622Q-R  0.947634
# 3 2004-02-11  CWT  9.054352        0.0           0.0  GSWXLY-R  0.934181
# 4 2004-02-11  BLL  6.898143        0.0           0.0  VFT0VQ-R  0.922862
#
#    totalRevenue     totalDebt  fullTimeEmployees   Oil        Gold  \
# 0  3.459800e+10  1.898000e+10            12591.0  34.0  410.200012
# 1  1.918329e+09  2.401210e+08             3700.0  34.0  410.200012
# 2           NaN           NaN                NaN  34.0  410.200012
# 3  8.067350e+08  1.184904e+09             1192.0  34.0  410.200012
# 4  1.323900e+10  8.925000e+09            21500.0  34.0  410.200012
#
#    USD to Yuan  industry_Advertising Agencies  industry_Aerospace & Defense  \
# ...

# %%
df.shape
# Out:
# (37360, 146)

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Date                                               0.000000
# Comp                                               0.000000
# Close                                              0.186804
# Dividends                                          0.186777
# Stock Splits                                       0.186777
# CompID                                             0.000000
# Score                                              0.000000
# totalRevenue                                       0.314963
# totalDebt                                          0.314240
# fullTimeEmployees                                  0.364052
# Oil                                                0.002141
# Gold                                               0.004283
# USD to Yuan                                        0.004283
# industry_Advertising Agencies                      0.000000
# industry_Aerospace & Defense                       0.000000
# industry_Agricultural Inputs                       0.000000
# ...

# %%
df.describe()
# Out:
#                Close     Dividends  Stock Splits         Score  totalRevenue  \
# count   30381.000000  30382.000000  30382.000000  37360.000000  2.559300e+04
# mean      189.726408      0.006433      0.000313      0.731634  1.704548e+10
# std      3789.032540      0.071881      0.025833      0.118071  4.084770e+10
# min        -2.483357      0.000000      0.000000      0.413554 -6.253500e+07
# 25%        19.607342      0.000000      0.000000      0.655228  1.622000e+09
# 50%        36.065784      0.000000      0.000000      0.743032  5.116700e+09
# 75%        64.683914      0.000000      0.000000      0.813181  1.425100e+10
# max    441225.000000      4.850000      3.000000      0.987225  3.783230e+11
#
#           totalDebt  fullTimeEmployees           Oil          Gold  \
# count  2.562000e+04       23759.000000  37280.000000  37200.000000
# mean   8.532437e+09       31358.336252     68.657640   1177.949247
# std    1.625189e+10       60257.456781     22.594650    421.826678
# ...

# %% [markdown]
# ## Regresja

# %%
df_clear = df.dropna()

# %%
y = 'Score'
x_cols = [col for col in df.columns if col != y]
x_cols.remove('Date')
x_cols.remove('Comp')
x_cols.remove('CompID')

# %%
X_train, X_test, y_train, y_test = train_test_split(df_clear[x_cols], df_clear[y], test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
y_pred.shape
# Out:
# (7043,)

# %%
y_test.shape
# Out:
# (7043,)

# %% [markdown]
# https://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

# %%
print(regressor.intercept_, regressor.coef_, sep='\n')
# Out:
# 0.8021973059024471
# [ 1.99552589e-05  3.33982049e-02 -1.60271430e-02  1.42231798e-13
#   6.83001629e-14 -3.43131456e-08  1.35884793e-03 -6.40245360e-05
#  -1.39990410e-02  5.91192801e-02  3.47619458e-03  6.15739465e-03
#  -2.81615796e-03  3.07188303e-02 -2.26839062e-02  2.13570884e-02
#   2.53848045e-02  4.88812885e-02  2.67498768e-02 -1.12883733e-01
#  -1.34052672e-02 -7.07938661e-02  1.24686464e-02  2.10011225e-02
#   3.71788723e-02  1.53133110e-02  1.21346959e-01  4.10400462e-02
#   3.09637518e-02 -1.42481337e-02  1.71634428e-02  8.16302650e-03
#  -3.42681279e-02 -3.60635242e-02  7.68244108e-02 -1.03364297e-02
#  -2.28345360e-02  3.45710671e-02  1.32615728e-02  6.33634150e-02
#  -3.38878309e-03  1.23081100e-02 -3.24147566e-02 -5.08013267e-02
#  -5.58966648e-02 -8.72672681e-03  3.30149121e-02  1.66404384e-02
#  -5.49819765e-03 -7.24488200e-02  3.16801266e-02  4.50714502e-02
#   2.43711947e-02 -7.46924159e-02 -4.89551367e-03 -2.21870892e-02
# ...

# %% [markdown]
# https://subscription.packtpub.com/book/data/9781789808452/1/ch01lvl1sec12/computing-regression-accuracy

# %%
def print_result(y_test, y_pred):
    print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred), 2)) 
    print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred), 2)) 
    print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred), 2)) 
    print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred), 2)) 
    print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))

# %%
print_result(y_test, y_pred)
# Out:
# Mean absolute error = 0.09
# Mean squared error = 0.01
# Median absolute error = 0.07
# Explain variance score = 0.15
# R2 score = 0.15
